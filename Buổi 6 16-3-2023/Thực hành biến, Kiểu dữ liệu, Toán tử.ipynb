# %% [markdown]
# # Bài 1
# ![image.png](attachment:image.png)

# %%
diem_toan = 7
diem_ly = 8
diem_hoa = 9
diem_trung_binh = (diem_toan + diem_ly + diem_hoa)/3

# %%
print(diem_trung_binh)
print(diem_trung_binh >= 8)
print(diem_trung_binh>=6 and diem_trung_binh <8)
print(diem_trung_binh <6)
# Out:
# 8.0
# True
# False
# False

# %% [markdown]
# # Bài 2
# ![image.png](attachment:image.png)

# %%
a = 90 # tỉ lệ tham gia khóa học
b = 85 # tỉ lệ hoàn thành khóa học trên trang learn
c = 8.0 # điểm thi cuối khóa

# %%
print(a)
print(b)
print(c)
print(a >= 75 and b >= 80 and c >=7.5)
# Out:
# 90
# 85
# 8.0
# True

# %% [markdown]
# # Bài 3
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
b = (33/60)*1000
c = (b*(60+72))/1000
print("mỗi phút tàu đi được số m")
print(b)
print("sau 1h 12p tàu đi được số km")
print(c)
# Out:
# mỗi phút tàu đi được số m
# 550.0
# sau 1h 12p tàu đi được số km
# 72.6

# %% [markdown]
# # Bài 4
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = 16
b = 10

current_area = a*b
new_area = (a+4)*b

result = (new_area - current_area)/current_area * 100
print("dien tich hien tai")
print(current_area)
print("dien tich mới")
print(new_area)
print("% dien tich tăng lên")
print(result)
# Out:
# dien tich hien tai
# 160
# dien tich mới
# 200
# % dien tich tăng lên
# 25.0

# %% [markdown]
# # Bài 5
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
xedap = 12 # van toc nguoi di xe dap
xemay = 36 # van toc nguoi di xe may
khoang_cach = 48
hieu_van_toc = 36-12
x = khoang_cach/hieu_van_toc # thoi gian 2 xe gap nhau
print("số giờ để xe máy đuổi kịp xe đạp là")
print(x)
# Out:
# số giờ để xe máy đuổi kịp xe đạp là
# 2.0

# %%
a = 7
b = 9
if (a > b)
print("haha")
else
print("hihi")
end if
# Out:
#   Cell In[11], line 3
#     if (a > b)
#               ^
# SyntaxError: expected ':'
